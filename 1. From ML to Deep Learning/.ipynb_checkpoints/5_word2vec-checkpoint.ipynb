# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
# Out:
# C:\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
import gc
gc.collect()
# Out:
# 7

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'originated', 'anarchism', 'term', 'of', 'originated', 'term', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.137650
# Nearest to at: townshend, depressant, ape, profitable, interdisciplinary, faustus, queene, millet,
# Nearest to nine: dismisses, ruiz, cooled, regulus, tread, atheists, robot, gutenberg,
# Nearest to system: dancer, tracts, succeeded, unbundling, tierra, contraindicated, heydrich, layer,
# Nearest to called: reunified, meets, petersen, iic, heinous, ashland, kolbe, ctrl,
# Nearest to world: prisoners, marsalis, overlaid, farewell, infirmary, duets, xj, armadillos,
# Nearest to time: measures, cdp, chariot, privateers, parchment, pours, videos, recognises,
# Nearest to eight: filipinos, novgorod, connoisseur, expect, glenn, truncated, yorktown, litchfield,
# Nearest to a: lifeforms, tolkien, fa, unprofessional, cleese, courteous, nunnery, parsers,
# Nearest to will: windows, phoenicia, vital, archivist, keegan, philo, pfc, scouring,
# Nearest to while: meanings, fets, gunboats, lcd, float, woodland, teimanim, prefixes,
# Nearest to in: jitter, syndicalists, brussels, putonghua, realpolitik, nagel, gasoline, treaties,
# Nearest to of: gaylord, mitral, demobilization, them, specializations, aspiring, thoroughly, nanjing,
# Nearest to more: polypeptides, puget, trinitarian, insecticides, tampa, boulder, expose, adjoining,
# Nearest to not: barrington, privation, halfway, screws, cyanobacteria, septimania, twig, frail,
# Nearest to people: resigning, lecture, favorites, xbox, prototypical, genetically, prospect, tremors,
# Nearest to s: idempotent, release, katha, pretenders, microcomputers, dominion, constructs, dualities,
# Average loss at step 2000: 4.372020
# Average loss at step 4000: 3.868032
# Average loss at step 6000: 3.787243
# Average loss at step 8000: 3.684116
# Average loss at step 10000: 3.618240
# Nearest to at: in, ape, steeped, ios, depressant, for, anhalt, on,
# Nearest to nine: eight, six, seven, five, zero, three, four, two,
# Nearest to system: layer, tierra, succeeded, backwardness, robin, anzus, contraindicated, cincinnati,
# Nearest to called: petersen, kolbe, views, hating, heinous, equipping, excerpt, typically,
# Nearest to world: arbitrage, tui, anti, duets, xj, infirmary, balaenoptera, my,
# Nearest to time: profound, measures, urbanization, shilton, jeannie, pentagon, waves, object,
# Nearest to eight: six, nine, seven, four, five, three, two, zero,
# Nearest to a: the, this, missionaries, unprofessional, cams, responding, lifeforms, virginity,
# Nearest to will: would, can, dylan, must, fistful, functionaries, allowed, jp,
# Nearest to while: woodland, embassies, azali, sensors, for, jackals, cashmere, vm,
# Nearest to in: of, with, on, at, from, and, realisation, between,
# Nearest to of: in, riemann, for, proverbial, realm, thoroughly, lamarckian, auras,
# Nearest to more: megali, insecticides, mimics, very, edd, detriment, straczynski, upload,
# Nearest to not: they, it, also, twig, herder, often, treasures, sometimes,
# Nearest to people: xbox, polymaths, both, multicast, resigning, refurbished, prototypical, clairvaux,
# Nearest to s: his, idempotent, and, dong, chuck, batted, thaddeus, doth,
# Average loss at step 12000: 3.607020
# Average loss at step 14000: 3.570504
# Average loss at step 16000: 3.412587
# Average loss at step 18000: 3.453597
# Average loss at step 20000: 3.545191
# Nearest to at: in, from, on, for, ios, herg, is, oysters,
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to system: layer, impossibility, anzus, robin, succeeded, strengthens, refrigeration, workers,
# Nearest to called: petersen, kolbe, equipping, typically, used, cherubim, abolished, polymorphic,
# Nearest to world: arbitrage, tui, xj, lesotho, jiao, prisoners, duets, infirmary,
# Nearest to time: profound, pentagon, urbanization, years, measures, shilton, object, waves,
# Nearest to eight: six, seven, nine, five, four, three, two, zero,
# Nearest to a: no, the, this, responding, another, explode, unprofessional, ascending,
# Nearest to will: would, can, may, must, could, to, should, dylan,
# Nearest to while: for, cauchy, azali, woodland, jackals, and, bootleg, surreptitiously,
# Nearest to in: at, on, from, stupor, with, between, around, divergences,
# Nearest to of: for, including, strictness, riemann, in, antlia, kathmandu, same,
# Nearest to more: very, less, megali, rather, most, greater, spearheaded, wakefield,
# Nearest to not: they, it, also, generally, herder, twig, arles, still,
# Nearest to people: both, molly, clairvaux, lecture, sublimation, xbox, centrioles, paddles,
# Nearest to s: iraqis, bombing, lemy, numeration, moulds, tocharians, microcomputers, dong,
# Average loss at step 22000: 3.507893
# Average loss at step 24000: 3.487284
# Average loss at step 26000: 3.477442
# Average loss at step 28000: 3.477459
# Average loss at step 30000: 3.504948
# Nearest to at: in, cooperated, arbitrage, isomerism, during, supposing, on, depressant,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to system: internalism, anzus, impossibility, beatings, pursue, pokes, kapital, cincinnati,
# Nearest to called: petersen, used, word, kolbe, petr, cherubim, adas, abolished,
# Nearest to world: arbitrage, tui, jiao, lesotho, anti, xj, reconstruction, balaenoptera,
# Nearest to time: revolt, pentagon, profound, knudsen, whenever, waves, urbanization, measures,
# Nearest to eight: nine, five, six, seven, four, three, zero, two,
# Nearest to a: responding, no, the, ascending, barge, any, decorate, mummification,
# Nearest to will: would, can, may, could, must, should, to, dylan,
# Nearest to while: for, although, cauchy, but, is, brawl, as, confederates,
# Nearest to in: of, on, at, realisation, from, and, with, between,
# Nearest to of: in, for, and, from, including, disprove, lamarckian, konoe,
# Nearest to more: less, very, most, megali, larger, greater, rather, geneva,
# Nearest to not: they, generally, still, arles, it, calorimeter, to, herder,
# Nearest to people: molly, centuries, jews, insertions, revision, lancashire, genetically, lecture,
# Nearest to s: his, austerity, batted, neurotoxicity, her, and, asteroid, moraine,
# Average loss at step 32000: 3.499219
# Average loss at step 34000: 3.499337
# Average loss at step 36000: 3.452633
# Average loss at step 38000: 3.298479
# Average loss at step 40000: 3.429817
# Nearest to at: on, during, supposing, profitable, faustus, bbbb, interdisciplinary, rubbish,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to system: systems, impossibility, kapital, pokes, heck, beatings, internalism, anzus,
# Nearest to called: petersen, cherubim, petr, see, used, typically, forensics, adas,
# Nearest to world: jiao, anti, mayan, arbitrage, balaenoptera, tui, jeter, lesotho,
# Nearest to time: profound, pentagon, way, days, revolt, knudsen, demonic, day,
# Nearest to eight: nine, seven, six, four, five, three, zero, one,
# Nearest to a: the, another, ascending, responding, no, any, tra, chained,
# Nearest to will: would, can, could, may, must, should, to, might,
# Nearest to while: although, but, when, for, are, where, however, before,
# Nearest to in: of, and, biplane, from, during, on, goalkeeper, for,
# Nearest to of: in, for, vijayanagara, hamsters, mayhew, metamorphism, including, vla,
# Nearest to more: less, most, very, greater, longer, larger, rather, integrable,
# Nearest to not: generally, they, still, often, calorimeter, it, atrial, arles,
# Nearest to people: molly, unclear, insertions, sinhalese, voted, favorites, jews, centuries,
# Nearest to s: dong, his, tarquinius, austerity, unplugged, sacramental, warrior, lowercase,
# Average loss at step 42000: 3.436781
# Average loss at step 44000: 3.451428
# Average loss at step 46000: 3.453389
# Average loss at step 48000: 3.348298
# Average loss at step 50000: 3.386329
# Nearest to at: profitable, from, stabilizing, rubbish, auxiliaries, during, depressant, cooperated,
# Nearest to nine: eight, seven, six, four, three, five, zero, two,
# Nearest to system: systems, kapital, pokes, beatings, heck, appropriateness, reform, executors,
# Nearest to called: petersen, named, adas, behistun, cherubim, likewise, used, normative,
# Nearest to world: anti, jiao, mayan, balaenoptera, lesotho, aeolian, duets, roddenberry,
# Nearest to time: days, year, kul, cromarty, way, day, profound, necessities,
# Nearest to eight: six, seven, nine, four, five, three, zero, two,
# Nearest to a: another, the, mummification, any, chained, regarded, mecklenburg, inspectors,
# Nearest to will: would, can, could, may, must, should, cannot, might,
# Nearest to while: when, however, although, but, after, where, for, began,
# Nearest to in: from, during, within, on, since, ninhursag, of, around,
# Nearest to of: and, in, kathmandu, relaxation, czech, including, supplementing, from,
# Nearest to more: less, most, very, greater, longer, larger, rather, allude,
# Nearest to not: they, generally, still, atrial, snaps, often, zoot, twig,
# Nearest to people: men, molly, jews, unclear, tumble, revision, children, members,
# Nearest to s: his, culprit, and, eur, libyan, austerity, janissaries, babes,
# Average loss at step 52000: 3.435489
# Average loss at step 54000: 3.431487
# Average loss at step 56000: 3.438668
# Average loss at step 58000: 3.394705
# Average loss at step 60000: 3.390745
# Nearest to at: in, profitable, faustus, during, cooperated, supposing, rubbish, ablative,
# Nearest to nine: eight, six, seven, four, five, three, zero, two,
# Nearest to system: systems, pokes, kapital, reform, excitable, change, tui, impossibility,
# Nearest to called: used, named, petersen, known, likewise, referred, adas, errand,
# Nearest to world: anti, jiao, lesotho, balaenoptera, largest, continent, nationwide, invaders,
# Nearest to time: cromarty, kul, curlers, argyle, motherboards, period, experimental, italic,
# Nearest to eight: six, nine, seven, four, five, three, zero, two,
# Nearest to a: another, the, any, awareness, ascending, no, every, chained,
# Nearest to will: would, could, may, can, must, should, might, cannot,
# Nearest to while: although, when, but, however, though, where, including, after,
# Nearest to in: within, during, of, at, including, since, on, realisation,
# Nearest to of: for, including, in, jester, konoe, specializations, morbid, like,
# Nearest to more: less, very, most, rather, greater, larger, longer, spearheaded,
# Nearest to not: still, generally, they, buick, we, atrial, you, snaps,
# Nearest to people: men, molly, jews, those, revision, members, children, persons,
# Nearest to s: muharram, ant, austerity, aboard, eur, thaddeus, horsepower, hypomanic,
# Average loss at step 62000: 3.238662
# Average loss at step 64000: 3.250416
# Average loss at step 66000: 3.404503
# Average loss at step 68000: 3.396680
# Average loss at step 70000: 3.360348
# Nearest to at: medicaid, candida, pulses, in, during, profitable, cooperated, on,
# Nearest to nine: eight, six, seven, five, four, three, zero, two,
# Nearest to system: systems, pokes, reform, parliamentary, tui, rstenberg, baldr, internalism,
# Nearest to called: named, referred, used, petersen, cherubim, word, lightest, known,
# Nearest to world: jiao, balaenoptera, continent, lesotho, recovery, nationwide, mayan, largest,
# Nearest to time: kul, argyle, once, curlers, cromarty, days, period, lieu,
# Nearest to eight: nine, six, seven, four, five, zero, three, two,
# Nearest to a: another, the, any, enough, ax, awareness, responding, cams,
# Nearest to will: would, can, could, may, must, should, might, cannot,
# Nearest to while: although, however, when, though, where, if, but, and,
# Nearest to in: during, within, on, until, from, including, between, since,
# Nearest to of: including, specializations, enormous, like, include, in, lichens, metamorphism,
# Nearest to more: less, most, very, rather, greater, larger, longer, extremely,
# Nearest to not: still, generally, now, never, usually, atrial, they, also,
# Nearest to people: men, molly, women, children, jews, persons, revision, parts,
# Nearest to s: whose, culprit, manuals, kazantzakis, vla, muharram, eur, isbn,
# Average loss at step 72000: 3.378619
# Average loss at step 74000: 3.348511
# Average loss at step 76000: 3.326511
# Average loss at step 78000: 3.352723
# Average loss at step 80000: 3.383013
# Nearest to at: during, in, around, footlights, faustus, on, cooperated, granularity,
# Nearest to nine: eight, seven, six, five, three, four, zero, two,
# Nearest to system: systems, pokes, impossibility, tui, parliamentary, internalism, reform, malawi,
# Nearest to called: used, named, known, referred, petersen, see, word, grounding,
# Nearest to world: balaenoptera, continent, frideric, lesotho, largest, boasting, jiao, xj,
# Nearest to time: days, kul, lieu, curlers, motherboards, felony, exemplifies, year,
# Nearest to eight: seven, six, nine, five, four, three, zero, one,
# Nearest to a: another, the, every, awareness, cams, virginity, any, mummification,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to while: although, though, when, however, but, during, after, and,
# Nearest to in: during, on, until, since, within, at, between, of,
# Nearest to of: including, konoe, in, jester, original, lamarckian, affiliate, entire,
# Nearest to more: less, very, greater, most, rather, larger, longer, better,
# Nearest to not: still, generally, now, usually, they, never, we, it,
# Nearest to people: men, children, jews, persons, parts, women, families, instances,
# Nearest to s: isbn, muharram, yemeni, ripper, horsepower, austerity, bn, rap,
# Average loss at step 82000: 3.404537
# Average loss at step 84000: 3.409485
# Average loss at step 86000: 3.392556
# Average loss at step 88000: 3.351950
# Average loss at step 90000: 3.360729
# Nearest to at: during, near, aqdas, around, arbitrage, depressant, contradict, in,
# Nearest to nine: seven, eight, six, five, four, zero, three, two,
# Nearest to system: systems, pokes, internalism, tui, parliamentary, asleep, executors, kapital,
# Nearest to called: named, used, referred, known, petersen, word, grounding, considered,
# Nearest to world: capture, superfluous, scout, mayan, continent, boasting, largest, balaenoptera,
# Nearest to time: kul, lieu, somebody, whenever, exemplifies, period, days, suppresses,
# Nearest to eight: seven, six, nine, five, four, three, zero, two,
# Nearest to a: another, the, responding, ascending, virginity, every, cams, any,
# Nearest to will: would, could, can, must, may, should, might, cannot,
# Nearest to while: although, though, but, when, however, were, during, and,
# Nearest to in: during, within, until, under, throughout, of, around, between,
# Nearest to of: including, for, enormous, in, konoe, polypeptides, dispensation, under,
# Nearest to more: less, very, most, greater, rather, larger, too, extremely,
# Nearest to not: still, generally, they, we, now, snaps, never, necessarily,
# Nearest to people: men, children, women, students, jews, instances, persons, revision,
# Nearest to s: isbn, culprit, parentage, whose, his, dunham, thalberg, horsepower,
# Average loss at step 92000: 3.399959
# Average loss at step 94000: 3.250057
# Average loss at step 96000: 3.355318
# Average loss at step 98000: 3.243059
# Average loss at step 100000: 3.359159
# Nearest to at: during, in, near, on, catches, contradict, arbitrage, faustus,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to system: systems, pokes, ashmore, tui, indictments, asleep, parliamentary, internalism,
# Nearest to called: named, referred, petersen, used, known, word, heartbreak, identifies,
# Nearest to world: largest, mayan, lesotho, scout, prisoners, groot, classmates, continent,
# Nearest to time: kul, year, days, period, motherboards, lieu, whenever, exemplifies,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to a: another, the, any, ascending, responding, awareness, instinctive, virginity,
# Nearest to will: would, could, can, must, may, should, might, cannot,
# Nearest to while: although, when, though, but, however, if, where, for,
# Nearest to in: during, within, at, until, throughout, from, on, of,
# Nearest to of: including, in, entire, and, guesses, from, natasha, panicked,
# Nearest to more: less, most, very, greater, larger, better, rather, extremely,
# Nearest to not: never, still, generally, completely, they, snaps, atrial, now,
# Nearest to people: men, children, jews, students, women, individuals, persons, those,
# Nearest to s: whose, his, muharram, isbn, culprit, her, the, leu,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
